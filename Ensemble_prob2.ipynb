# %% [markdown]
# #### Problem to find protein with max missense_ variant values

# %%
#Parsing the file from url

import pandas as pd
df = pd.read_csv('ftp://ftp.broadinstitute.org/pub/ExAC_release/release1/manuscript_data/ExAC.r1.sites.vep.canonical.table.gz', sep='\t')

# %%
df.columns   # Getting the header of all the columns present in the data
# Out:
# Index(['CHROM', 'POS', 'REF', 'ALT', 'ID', 'FILTER', 'AC_SAS', 'AC_AMR',
#        'AC_AFR', 'AC_Adj', 'AC_OTH', 'AC_Het', 'AC_NFE', 'AC_Hemi',
#        'AC_POPMAX', 'AC_MALE', 'AC_FEMALE', 'AC_CONSANGUINEOUS', 'AC_FIN',
#        'AC_Hom', 'AC', 'AC_EAS', 'AN_POPMAX', 'AN_SAS', 'AN_MALE', 'AN_Adj',
#        'AN_AMR', 'AN_EAS', 'AN_NFE', 'AN_AFR', 'AN_FEMALE', 'AN_FIN', 'AN_OTH',
#        'AN_CONSANGUINEOUS', 'AN', 'Hom_EAS', 'Hom_OTH', 'Hom_CONSANGUINEOUS',
#        'Hom_NFE', 'Hom_SAS', 'Hom_AMR', 'Hom_FIN', 'Hom_AFR', 'clinvar_mut',
#        'clinvar_measureset_id', 'clinvar_conflicted', 'clinvar_pathogenic',
#        'POPMAX', 'DOUBLETON_DIST', 'InbreedingCoeff', 'ESP_AC',
#        'ESP_AF_GLOBAL', 'ESP_AF_POPMAX', 'KG_AF_GLOBAL', 'KG_AC',
#        'KG_AF_POPMAX', 'VQSLOD', 'Gene', 'Feature', 'SYMBOL', 'CANONICAL',
#        'EXON', 'INTRON', 'Consequence', 'HGVSc', 'HGVSp', 'Amino_acids',
#        'SIFT', 'PolyPhen', 'LoF', 'LoF_filter', 'LoF_flags', 'LoF_info',
# ...

# %%
df1 = df[['Consequence', 'HGVSp']]    # Made a dataframe of two required columns having Consequence of variant and
                                      # Ensemble protein ID

# %%
#df2 = df1[df1['Consequence']=='missense_variant']  # Selected only missense_variant from Consequence column.

# %%
df2[] = df1.where(df1['Consequence']=='missense_variant')    # Selected only missense_variant from Consequence column.

# %%
df2.groupby('HGVSp').first()
# Out:
#                                      Consequence
# HGVSp
# ENSP00000000233.5:p.Ala104Thr   missense_variant
# ENSP00000000233.5:p.Ala125Ser   missense_variant
# ENSP00000000233.5:p.Ala133Thr   missense_variant
# ENSP00000000233.5:p.Ala7Val     missense_variant
# ENSP00000000233.5:p.Arg117Gln   missense_variant
# ENSP00000000233.5:p.Arg149Cys   missense_variant
# ENSP00000000233.5:p.Arg149His   missense_variant
# ENSP00000000233.5:p.Arg149Ser   missense_variant
# ENSP00000000233.5:p.Arg151Cys   missense_variant
# ENSP00000000233.5:p.Arg151His   missense_variant
# ENSP00000000233.5:p.Arg151Leu   missense_variant
# ENSP00000000233.5:p.Arg180Cys   missense_variant
# ENSP00000000233.5:p.Arg180His   missense_variant
# ENSP00000000233.5:p.Arg97Gln    missense_variant
# ENSP00000000233.5:p.Arg97Trp    missense_variant
# ENSP00000000233.5:p.Glu138Gln   missense_variant
# ENSP00000000233.5:p.Glu138Lys   missense_variant
# ENSP00000000233.5:p.Glu176Lys   missense_variant
# ...

# %%
df2[['col1', 'col2']] = df2['HGVSp'].str.split(':', n=1, expand=True)  # split the HGVSp column to separate Ensemble Proein ID
                                                                       # and change in amino acid
# Out:
# C:\Users\Pri\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df2[['col1','col2']].drop_duplicates().groupby('col1').count().sort_values('col2', ascending=False) # Got the unique Ensemble Protein ID
                                                                                                    # and counts the corresponding missense_variants
# Out:
#                     col2
# col1
# ENSP00000467141.1  12523
# ENSP00000381008.2   6523
# ENSP00000417498.3   4244
# ENSP00000353114.4   4194
# ENSP00000455507.2   3986
# ENSP00000357789.1   3600
# ENSP00000356224.5   3031
# ENSP00000436812.1   2986
# ENSP00000302716.4   2725
# ENSP00000380505.3   2685
# ENSP00000323856.4   2634
# ENSP00000350719.3   2505
# ENSP00000367263.4   2385
# ENSP00000262304.4   2353
# ENSP00000374490.5   2252
# ENSP00000384582.2   2206
# ENSP00000305941.3   2150
# ENSP00000330671.6   2077
# ENSP00000271588.4   2017
# ENSP00000221347.5   1925
# ENSP00000363827.3   1906
# ENSP00000441462.1   1894
# ENSP00000334319.8   1883
# ENSP00000358400.3   1870
# ENSP00000252999.3   1868
# ENSP00000406229.2   1859
# ENSP00000411096.1   1852
# ENSP00000357791.2   1818
# ENSP00000352608.2   1817
# ENSP00000265104.4   1765
# ...                  ...
# ENSP00000455775.1      1
# ENSP00000371117.3      1
# ENSP00000470167.1      1
# ENSP00000470052.1      1
# ...

# %%
# The Ensemble Protein of ID ENSP00000467141.1 has maximum number of 12523 missense_variants
